# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Academic-Performance-Dataset.csv")
missing_values = data.isnull().sum()
print("Missing values:\n", missing_values)
# Out:
# Missing values:
#  Rollno         0
# Name           2
# Gender         0
# Branch         0
# Attendence     0
# Phy_marks      1
# Che_marks      3
# EM1_marks      2
# PPS_marks      1
# SME_marks      0
# Total Marks    0
# Percentage     0
# dtype: int64

# %%
# delete 

# data_cleaned = data.dropna()
# data_cleaned  = data.dropna(axis =1)

# replace with mean median mode
mean_val = data["Che_marks"].mean()
mod_val = data["Che_marks"].mode()
# median_val = data["Che_marks"].median()
mean_val= round(float(mean_val), 2)
print(mod_val)
data["Che_marks"] = data["Che_marks"].fillna(mean_val)
# data
# Out:
# 0    80.76
# Name: Che_marks, dtype: float64

# %%
# tranform in new scale use square root
data['totalmarks_transform'] = np.sqrt(data['Total Marks'])
data['totalmarks_transform'] = data['totalmarks_transform'].round(2)
data
# Out:
#     Rollno       Name Gender Branch  Attendence  Phy_marks  Che_marks
# 0        1   Mohammed      M   Comp          72       62.0      98.00  \
# 1        2    Reyansh      M     IT          58       62.0      83.00
# 2        3      Aarav      M     IT          57      -20.0     100.00
# 3        4     Atharv      M     IT          60       89.0      83.00
# 4        5     Vivaan      M   Comp          85       90.0      80.76
# 5        6      Advik      M   ENTC          94       99.0      84.00
# 6        7       Ansh      M   ENTC          98       88.0      95.00
# 7        8     Ishaan      M   ENTC          75       66.0      51.00
# 8        9      Dhruv      M   ENTC          63        NaN      80.76
# 9       10  Siddharth      M   ENTC          96       67.0      78.00
# 10      11     Vihaan      M   ENTC          82       54.0      70.00
# 11      12        NaN      M     IT          75       64.0      67.00
# ...
